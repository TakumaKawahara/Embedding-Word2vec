# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [03:24, 153KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
print(words[:20])
print(int_words[:20])
print('Min:',min(int_words), 'Max:',max(int_words))
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']
# [5240, 3081, 11, 5, 194, 1, 3136, 45, 58, 155, 127, 741, 476, 10574, 133, 0, 27803, 1, 0, 102]
# Min: 0 Max: 63640

# %%
counter = np.zeros(max(int_words)+1)
for i in range(len(int_words)):
    counter[int_words[i]] += 1
np.sum(counter)
# Out:
# 16680599.0

# %%
freq = np.zeros_like(counter)
freq = counter/np.sum(counter)

# %%
import matplotlib.pyplot as plt
thre = 1e-5
plt.hist(freq, 50, range=(0, 0.008),weights=None, normed=False, log=True)
plt.vlines(x=thre, ymin=1e-2, ymax=1e6, color='r', linestyles='dotted')
plt.ylim(ymax=1e5)
plt.ylim(ymin=1e-1)
plt.show()

# %%
prob = np.zeros_like(counter)
prob = 1 - np.sqrt(thre/freq)
print('Min:',min(prob), 'Max:',max(prob))
# Out:
# Min: -4.27266520209 Max: 0.987463765777

# %%
plt.hist(prob, 50, range=(-5, 1),weights=None, normed=False, log=False)
plt.show()

# %%
print(counter[0:20])
print(freq[:20])
print(prob[:20])
print(words[:20])
print(int_words[:20])
# Out:
# [ 1061396.   593677.   416629.   411764.   372201.   325873.   316376.
#    264975.   250430.   192644.   183153.   131815.   125285.   118445.
#    116710.   115789.   114775.   112807.   111831.   109510.]
# [ 0.06363057  0.03559087  0.02497686  0.0246852   0.02231341  0.01953605
#   0.0189667   0.01588522  0.01501325  0.01154899  0.01098     0.00790229
#   0.00751082  0.00710076  0.00699675  0.00694154  0.00688075  0.00676277
#   0.00670426  0.00656511]
# [ 0.98746377  0.98323781  0.97999074  0.97987288  0.97883019  0.97737536
#   0.9770383   0.97490984  0.97419151  0.97057421  0.96982142  0.96442676
#   0.96351148  0.96247269  0.96219478  0.96204472  0.96187743  0.96154633
#   0.96137889  0.96097176]
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']
# [5240, 3081, 11, 5, 194, 1, 3136, 45, 58, 155, 127, 741, 476, 10574, 133, 0, 27803, 1, 0, 102]

# %%
import random
train_words = []
for i in range(len(int_words)):
    if prob[int_words[i]] < random.random():
        train_words.append(int_words[i]) # The final subsampled word list

# %%
len(train_words)
# Out:
# 4625280

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
# Solution
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    #randint(a, b) #a <= N < b であるようなランダムな整数 N を返す。
    
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)
    # Change from set to list

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embe_dding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
ini_weight = 0.001
with train_graph.as_default():
    # create softmax weight matrix here
    # Remark [num_classes, dim]
    softmax_w = {'wd': tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev = ini_weight))}
    # create softmax biases here
    softmax_b = {'bd': tf.Variable(tf.truncated_normal([n_vocab], stddev = ini_weight))}
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w['wd'], softmax_b['bd'], labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory 'checkpoints': File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4243 0.0438 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3913 0.0412 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.2707 0.0398 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3166 0.0406 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1696 0.0403 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.1539 0.0406 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.1221 0.0414 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0027 0.0411 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.8852 0.0411 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8342 0.0415 sec/batch
# Nearest to states: passages, baruch, miles, so, measurement, declined, technical, default,
# Nearest to people: from, promised, kind, reconnaissance, cjls, employing, shops, royal,
# Nearest to or: supply, drain, settings, prediction, site, conduct, mix, possess,
# Nearest to and: luxemburg, obtained, proposer, starting, arrow, religious, flanders, themed,
# Nearest to to: lake, s, without, destroys, darryl, serum, hellas, notorious,
# Nearest to other: dominican, hostels, jumping, without, sufferers, briefly, morisco, contamination,
# Nearest to was: six, one, unlike, system, crossroads, prevailed, business, throne,
# Nearest to than: tied, wildfire, suitable, commitments, addition, kilometres, separate, favored,
# Nearest to consists: localization, papeete, recognize, weapons, nice, ukrainians, firefighters, planted,
# Nearest to http: diligence, yamasaki, moore, churches, sds, auer, deliriants, papa,
# Nearest to discovered: ochino, architectures, romania, accessories, premarital, famous, complied, decisions,
# Nearest to rise: chattanooga, plays, objections, head, suggested, request, byte, preliminary,
# Nearest to hold: traced, fragments, cheaper, head, perceptions, retained, stage, connected,
# Nearest to units: favor, single, thrilled, disproportionately, wilhelmina, office, undefended, yuri,
# Nearest to universe: tenderness, analytical, animation, alterations, evelyn, iranians, calais, vyanjana,
# Nearest to running: attack, purpose, averaged, retaken, communications, dealt, loss, ethnologue,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.8430 0.0418 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.7798 0.0409 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7574 0.0402 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7246 0.0414 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.7071 0.0405 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.7152 0.0409 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7162 0.0409 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7056 0.0417 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6744 0.0413 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6777 0.0413 sec/batch
# Nearest to states: baruch, auditioning, maeterlinck, felidae, campeador, liqueurs, hubbard, economists,
# Nearest to people: cjls, bolsheviks, employing, from, reconnaissance, finkelstein, af, promised,
# Nearest to or: drain, supply, avars, hovd, settings, denser, possess, prediction,
# Nearest to and: luxemburg, proposer, cleverness, flanders, rigorous, themed, reconstituted, apportioned,
# Nearest to to: darryl, hellas, serum, lake, relocated, destroys, without, nationalities,
# Nearest to other: dominican, hostels, sufferers, morisco, intersection, ambroise, jumping, muscled,
# Nearest to was: vile, loach, six, prevailed, frigid, tailless, ernst, crossroads,
# Nearest to than: wildfire, suitable, tied, commitments, suitor, cheeses, congregations, livingston,
# Nearest to consists: localization, papeete, ukrainians, recognize, battlefields, laborers, firefighters, planted,
# Nearest to http: diligence, tabletop, papa, escobar, yamasaki, moore, sds, churches,
# Nearest to discovered: ochino, romania, premarital, decoration, architectures, farid, accessories, hee,
# Nearest to rise: chattanooga, auguste, ensign, chechen, objections, corona, preliminary, bonding,
# Nearest to hold: perceptions, socialism, traced, marry, plateaus, salian, fragments, inconceivable,
# Nearest to units: thrilled, favor, plastic, yuri, single, wilhelmina, disproportionately, modernist,
# Nearest to universe: analytical, evelyn, alterations, tenderness, animation, circuits, calais, iranians,
# Nearest to running: drastically, retaken, averaged, utilize, attack, dealt, mortals, household,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6943 0.0413 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6350 0.0401 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6573 0.0404 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6692 0.0407 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6090 0.0406 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5916 0.0409 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6196 0.0411 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6082 0.0406 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6284 0.0407 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6155 0.0404 sec/batch
# Nearest to states: auditioning, baruch, maeterlinck, multiparty, campeador, felidae, hubbard, economists,
# Nearest to people: cjls, bolsheviks, from, employing, finkelstein, reconnaissance, furtherance, promised,
# Nearest to or: hovd, possess, settings, drain, algorithm, prediction, supply, avars,
# Nearest to and: luxemburg, proposer, cleverness, rigorous, landis, flanders, apportioned, reconstituted,
# Nearest to to: hellas, darryl, serum, lake, probus, eponym, forgetful, nationalities,
# Nearest to other: dominican, hostels, sufferers, morisco, ambroise, officiel, muscled, dictate,
# Nearest to was: vile, throne, vla, ernst, loach, jekyll, tailless, frigid,
# Nearest to than: wildfire, suitable, commitments, suitor, congregations, addition, tied, cosets,
# Nearest to consists: papeete, localization, battlefields, ukrainians, firefighters, laborers, recognize, userspace,
# Nearest to http: tabletop, papa, diligence, ley, deliriants, yamasaki, curran, escobar,
# Nearest to discovered: ochino, premarital, romania, farid, decoration, evocation, architectures, hee,
# Nearest to rise: chattanooga, ensign, auguste, chechen, schismatic, mayonnaise, objections, corona,
# Nearest to hold: perceptions, salian, marry, bode, traced, socialism, clogged, plateaus,
# Nearest to units: thrilled, wilhelmina, plastic, single, undefended, treize, stitch, favor,
# Nearest to universe: analytical, evelyn, alterations, tng, tenderness, mathbf, riordan, animation,
# Nearest to running: scouring, drastically, retaken, averaged, utilize, communications, detonate, mortals,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6167 0.0425 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5700 0.0408 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5762 0.0417 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5708 0.0403 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5433 0.0400 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5257 0.0407 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5219 0.0407 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5794 0.0402 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5496 0.0402 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5108 0.0404 sec/batch
# Nearest to states: baruch, auditioning, maeterlinck, campeador, multiparty, canada, cabell, liberty,
# Nearest to people: bolsheviks, cjls, from, finkelstein, furtherance, reconnaissance, employing, digby,
# Nearest to or: settings, hovd, assess, possess, supply, prediction, drain, wrexham,
# Nearest to and: luxemburg, cleverness, proposer, landis, rigorous, flanders, infringed, apportioned,
# Nearest to to: hellas, darryl, probus, nationalities, deviant, forgetful, serum, lake,
# Nearest to other: dominican, hostels, morisco, muscled, sufferers, officiel, ambroise, dictate,
# Nearest to was: throne, vile, vla, jekyll, loach, mendeleev, prevailed, ernst,
# Nearest to than: wildfire, suitable, commitments, congregations, rascal, suitor, cheeses, scalars,
# Nearest to consists: localization, papeete, battlefields, ukrainians, firefighters, laborers, speck, userspace,
# Nearest to http: htm, papa, tabletop, edu, ley, sockets, catmull, existentialists,
# Nearest to discovered: ochino, romania, premarital, farid, evocation, decoration, hee, architectures,
# Nearest to rise: ensign, auguste, chattanooga, chechen, schismatic, criture, corona, mayonnaise,
# Nearest to hold: perceptions, salian, marry, traced, socialism, clogged, inconceivable, bode,
# Nearest to units: thrilled, wilhelmina, plastic, single, treize, undefended, localities, stitch,
# Nearest to universe: analytical, tng, evelyn, mathbf, alterations, riordan, tenderness, animation,
# Nearest to running: scouring, drastically, retaken, communications, hew, averaged, rcmp, beans,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5153 0.0421 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4926 0.0401 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4755 0.0405 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4866 0.0406 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4514 0.0414 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4986 0.0410 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4690 0.0310 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.3963 0.0414 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.3623 0.0414 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3467 0.0408 sec/batch
# Nearest to states: multiparty, campeador, auditioning, baruch, maeterlinck, prosperous, cabell, canada,
# Nearest to people: cjls, bolsheviks, from, finkelstein, digby, reconnaissance, furtherance, horde,
# Nearest to or: settings, hovd, assess, wrexham, prediction, drain, entranced, supply,
# Nearest to and: cleverness, luxemburg, proposer, landis, rigorous, caucasian, redlich, flanders,
# Nearest to to: hellas, darryl, probus, forgetful, nationalities, deviant, lake, permissions,
# Nearest to other: dominican, hostels, sufferers, morisco, muscled, officiel, ambroise, dictate,
# Nearest to was: vile, throne, jekyll, vla, prevailed, pilgrims, libya, loach,
# Nearest to than: wildfire, suitable, rascal, commitments, congregations, suitor, cheeses, scalars,
# Nearest to consists: papeete, localization, battlefields, speck, ukrainians, laborers, firefighters, recognize,
# Nearest to http: htm, papa, edu, tabletop, catmull, eliade, moore, sockets,
# Nearest to discovered: ochino, romania, evocation, farid, premarital, decoration, hee, grape,
# Nearest to rise: ensign, auguste, schismatic, mayonnaise, corona, incessant, chechen, yueh,
# Nearest to hold: perceptions, marry, traced, bode, salian, inconceivable, socialism, clogged,
# Nearest to units: thrilled, plastic, scorch, single, wilhelmina, treize, stitch, fluorescence,
# Nearest to universe: analytical, tng, alterations, plze, evelyn, mathbf, tenderness, begs,
# Nearest to running: scouring, drastically, hew, retaken, communications, rcmp, utilize, gurps,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.3547 0.0432 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.3381 0.0413 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3095 0.0406 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4133 0.0412 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.3754 0.0396 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3936 0.0402 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3444 0.0417 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.2968 0.0404 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3297 0.0403 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3492 0.0413 sec/batch
# Nearest to states: campeador, multiparty, prosperous, canada, cabell, baruch, pcmcia, auditioning,
# Nearest to people: cjls, bolsheviks, from, horde, reconnaissance, finkelstein, interceptions, digby,
# Nearest to or: settings, hovd, wrexham, assess, supply, basslines, drain, entranced,
# Nearest to and: cleverness, luxemburg, proposer, landis, redlich, rigorous, infringed, caucasian,
# Nearest to to: hellas, darryl, probus, forgetful, permissions, deviant, destroys, justine,
# Nearest to other: dominican, hostels, muscled, morisco, sufferers, officiel, dictate, ambroise,
# Nearest to was: vile, jekyll, vla, throne, prevailed, mendeleev, libya, malign,
# Nearest to than: wildfire, suitable, congregations, rascal, commitments, cheeses, dragster, suitor,
# Nearest to consists: localization, papeete, speck, battlefields, firefighters, coefficient, steel, ukrainians,
# Nearest to http: htm, edu, papa, sockets, tabletop, catmull, php, existentialists,
# Nearest to discovered: ochino, romania, farid, decoration, evocation, premarital, grape, hee,
# Nearest to rise: ensign, incessant, objections, yueh, fortuitous, lien, chechen, auguste,
# Nearest to hold: perceptions, clogged, inconceivable, bode, hulbert, marry, salian, anemia,
# Nearest to units: thrilled, scorch, plastic, stitch, fluorescence, treize, upwards, humps,
# Nearest to universe: analytical, tng, alterations, mathbf, evelyn, tenderness, catalysis, riordan,
# Nearest to running: scouring, drastically, rcmp, hew, retaken, utilize, gurps, communications,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3856 0.0422 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.2979 0.0403 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3233 0.0408 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3023 0.0407 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3515 0.0406 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3679 0.0411 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.2776 0.0402 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.2681 0.0407 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3094 0.0411 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2793 0.0413 sec/batch
# Nearest to states: multiparty, campeador, prosperous, cabell, canada, baruch, pcmcia, maeterlinck,
# Nearest to people: cjls, bolsheviks, from, horde, takings, reconnaissance, finkelstein, interceptions,
# Nearest to or: settings, hovd, wrexham, basslines, assess, entranced, certify, possess,
# Nearest to and: cleverness, luxemburg, rigorous, proposer, redlich, landis, lactamase, infringed,
# Nearest to to: hellas, darryl, probus, deviant, forgetful, permissions, nationalities, destroys,
# Nearest to other: dominican, hostels, muscled, morisco, sufferers, officiel, ambroise, dictate,
# Nearest to was: vile, vla, jekyll, throne, mendeleev, pilgrims, prevailed, crossroads,
# Nearest to than: suitable, wildfire, rascal, badgers, commitments, suitor, congregations, cheeses,
# Nearest to consists: localization, papeete, ukrainians, speck, firefighters, battlefields, laborers, whdh,
# Nearest to http: htm, edu, papa, php, catmull, sockets, tetrarchs, tabletop,
# Nearest to discovered: ochino, romania, decoration, farid, evocation, grape, premarital, orbit,
# Nearest to rise: orlogsflag, objections, chechen, schismatic, corona, yueh, lien, ensign,
# Nearest to hold: perceptions, inconceivable, clogged, bode, hulbert, marry, socialism, commission,
# Nearest to units: thrilled, scorch, upwards, plastic, treize, stitch, fluorescence, humps,
# Nearest to universe: analytical, tng, alterations, mathbf, evelyn, catalysis, tenderness, plze,
# Nearest to running: scouring, drastically, rcmp, retaken, gurps, retort, amplification, utilize,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2927 0.0421 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.2877 0.0413 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2715 0.0408 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2749 0.0410 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.2988 0.0421 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3015 0.0399 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3211 0.0401 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3070 0.0403 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2434 0.0408 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2594 0.0421 sec/batch
# Nearest to states: multiparty, campeador, cabell, prosperous, baruch, maeterlinck, klm, pcmcia,
# Nearest to people: cjls, bolsheviks, from, horde, finkelstein, reconnaissance, takings, digby,
# Nearest to or: settings, hovd, assess, basslines, wrexham, entranced, possess, certify,
# Nearest to and: cleverness, luxemburg, rigorous, proposer, redlich, landis, lactamase, caucasian,
# Nearest to to: hellas, darryl, forgetful, nationalities, deviant, probus, permissions, rammed,
# Nearest to other: dominican, muscled, hostels, sufferers, morisco, dictate, officiel, domicile,
# Nearest to was: vile, vla, converted, unlike, libya, mendeleev, jekyll, malign,
# Nearest to than: suitable, commitments, rascal, wildfire, badgers, congregations, browning, suitor,
# Nearest to consists: localization, papeete, ukrainians, firefighters, speck, battlefields, laborers, coahuila,
# Nearest to http: htm, edu, php, papa, catmull, sockets, tetrarchs, www,
# Nearest to discovered: romania, ochino, farid, decoration, evocation, orbit, grape, electronegative,
# Nearest to rise: orlogsflag, chechen, lien, objections, yueh, cimbri, climatic, ensign,
# Nearest to hold: perceptions, clogged, inconceivable, bode, hulbert, commission, marry, jew,
# Nearest to units: thrilled, upwards, scorch, treize, plastic, stitch, undefended, humps,
# Nearest to universe: analytical, evelyn, tng, alterations, tenderness, plze, mathbf, catalysis,
# Nearest to running: scouring, drastically, rcmp, gurps, retaken, retort, amplification, toby,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2697 0.0424 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2099 0.0408 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3011 0.0403 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3012 0.0281 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3264 0.0278 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2496 0.0280 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2142 0.0276 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2759 0.0277 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1463 0.0281 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2296 0.0280 sec/batch
# Nearest to states: multiparty, campeador, cabell, prosperous, klm, baruch, department, canada,
# Nearest to people: cjls, bolsheviks, from, horde, finkelstein, interceptions, takings, reconnaissance,
# Nearest to or: settings, hovd, assess, basslines, supply, certify, possess, wrexham,
# Nearest to and: cleverness, luxemburg, proposer, redlich, rigorous, landis, infringed, intel,
# Nearest to to: hellas, darryl, nationalities, deviant, forgetful, probus, princip, rammed,
# Nearest to other: dominican, hostels, muscled, morisco, sufferers, officiel, domicile, heralding,
# Nearest to was: vile, converted, vla, unlike, malign, mendeleev, libya, nailed,
# Nearest to than: suitable, commitments, badgers, wildfire, rascal, browning, suitor, congregations,
# Nearest to consists: localization, papeete, ukrainians, coahuila, speck, laborers, whdh, firefighters,
# Nearest to http: htm, edu, php, catmull, sockets, papa, www, tetrarchs,
# Nearest to discovered: romania, ochino, decoration, farid, evocation, orbit, grape, electronegative,
# Nearest to rise: orlogsflag, chechen, auguste, climatic, lien, cimbri, corona, objections,
# Nearest to hold: perceptions, clogged, inconceivable, hulbert, bode, commission, serb, socialism,
# Nearest to units: scorch, upwards, thrilled, treize, humps, plastic, stitch, nanometres,
# Nearest to universe: analytical, evelyn, tng, plze, alterations, tenderness, disputing, vuk,
# Nearest to running: scouring, rcmp, gurps, drastically, retaken, retort, sanjaks, flagship,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2493 0.0289 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2355 0.0277 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2795 0.0144 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1611 0.0281 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1802 0.0277 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1209 0.0279 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1276 0.0280 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1588 0.0280 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1804 0.0278 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1161 0.0277 sec/batch
# Nearest to states: campeador, multiparty, klm, prosperous, cabell, department, canada, violated,
# Nearest to people: cjls, horde, bolsheviks, from, takings, finkelstein, tangiers, af,
# Nearest to or: settings, hovd, basslines, wrexham, assess, supply, certify, hrvatske,
# Nearest to and: cleverness, proposer, redlich, luxemburg, ugaritic, rigorous, landis, intel,
# Nearest to to: hellas, darryl, probus, forgetful, lake, deviant, nationalities, rammed,
# Nearest to other: dominican, hostels, muscled, morisco, sufferers, heralding, domicile, officiel,
# Nearest to was: vile, converted, vla, unlike, nailed, malign, mendeleev, prevailed,
# Nearest to than: suitable, commitments, browning, badgers, rascal, dragster, wildfire, congregations,
# Nearest to consists: localization, papeete, ukrainians, coahuila, whdh, speck, laborers, liberaci,
# Nearest to http: htm, edu, php, sockets, papa, catmull, html, www,
# Nearest to discovered: romania, decoration, ochino, farid, evocation, orbit, grape, electronegative,
# Nearest to rise: orlogsflag, chechen, lien, auguste, climatic, corona, incessant, cimbri,
# Nearest to hold: perceptions, clogged, inconceivable, bode, hulbert, serb, commission, pressburger,
# Nearest to units: upwards, scorch, thrilled, treize, gluon, humps, nanometres, stitch,
# Nearest to universe: tng, analytical, evelyn, plze, alterations, tenderness, catalysis, disputing,
# Nearest to running: scouring, gurps, rcmp, retort, drastically, retaken, sanjaks, amplification,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1973 0.0288 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1985 0.0278 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1640 0.0279 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0918 0.0282 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1519 0.0279 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1562 0.0279 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1274 0.0279 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1521 0.0280 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1692 0.0329 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1489 0.0367 sec/batch
# Nearest to states: prosperous, campeador, klm, cabell, multiparty, baruch, department, dissemination,
# Nearest to people: cjls, horde, takings, bolsheviks, from, tangiers, finkelstein, shops,
# Nearest to or: settings, hovd, hrvatske, wrexham, assess, basslines, possess, mothman,
# Nearest to and: cleverness, proposer, redlich, ugaritic, rigorous, luxemburg, intel, lactamase,
# Nearest to to: hellas, darryl, forgetful, probus, deviant, princip, lake, carrying,
# Nearest to other: dominican, hostels, muscled, morisco, sufferers, domicile, heralding, officiel,
# Nearest to was: vile, converted, unlike, mendeleev, vla, nailed, prevailed, crossroads,
# Nearest to than: suitable, browning, commitments, badgers, wildfire, dragster, rascal, suitor,
# Nearest to consists: localization, papeete, ukrainians, coahuila, speck, whdh, coefficient, planted,
# Nearest to http: htm, edu, php, sockets, html, www, catmull, papa,
# Nearest to discovered: decoration, romania, ochino, electronegative, farid, orbit, evocation, grape,
# Nearest to rise: orlogsflag, chechen, climatic, corona, auguste, lien, mayonnaise, cimbri,
# Nearest to hold: perceptions, clogged, inconceivable, serb, pressburger, hulbert, bode, provincial,
# Nearest to units: upwards, scorch, gluon, fluorescence, treize, humps, nanometres, stitch,
# Nearest to universe: analytical, evelyn, tng, alterations, disputing, plze, catalysis, tenderness,
# Nearest to running: scouring, gurps, drastically, retort, sanjaks, rcmp, retaken, amplification,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1621 0.0333 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1832 0.0278 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1364 0.0281 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1222 0.0279 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1731 0.0278 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1510 0.0279 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1787 0.0280 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1007 0.0278 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0988 0.0278 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1122 0.0280 sec/batch
# Nearest to states: prosperous, cabell, klm, multiparty, campeador, baruch, violated, department,
# Nearest to people: cjls, horde, from, takings, tangiers, bolsheviks, finkelstein, dislocation,
# Nearest to or: settings, hovd, assess, basslines, wrexham, hrvatske, mascarenes, possess,
# Nearest to and: cleverness, proposer, rigorous, redlich, intel, ugaritic, luxemburg, lactamase,
# Nearest to to: hellas, darryl, forgetful, nationalities, deviant, princip, probus, select,
# Nearest to other: dominican, muscled, morisco, hostels, sufferers, heralding, domicile, officiel,
# Nearest to was: vile, converted, mendeleev, vla, eprint, unlike, nailed, malign,
# Nearest to than: suitable, browning, commitments, rascal, badgers, wildfire, dragster, socialization,
# Nearest to consists: papeete, localization, ukrainians, coahuila, whdh, speck, subdivision, liberaci,
# Nearest to http: htm, edu, php, www, html, sockets, papa, catmull,
# Nearest to discovered: decoration, electronegative, romania, farid, ochino, orbit, evocation, grape,
# Nearest to rise: orlogsflag, chechen, climatic, auguste, lien, objections, petrarca, corona,
# Nearest to hold: clogged, perceptions, inconceivable, pressburger, serb, commission, bode, provincial,
# Nearest to units: upwards, scorch, gluon, treize, fluorescence, nanometres, humps, segmenting,
# Nearest to universe: analytical, evelyn, alterations, tng, catalysis, disputing, tenderness, plze,
# Nearest to running: scouring, gurps, retort, rcmp, sanjaks, drastically, maintainability, amplification,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1625 0.0294 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1286 0.0278 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1409 0.0280 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1506 0.0279 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1122 0.0296 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1063 0.0279 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1678 0.0284 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0733 0.0285 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1902 0.0281 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2016 0.0280 sec/batch
# Nearest to states: multiparty, cabell, baruch, klm, campeador, prosperous, violated, maeterlinck,
# Nearest to people: cjls, horde, tangiers, takings, from, finkelstein, bolsheviks, interceptions,
# Nearest to or: settings, hovd, wrexham, mascarenes, possess, assess, certify, basslines,
# Nearest to and: cleverness, luxemburg, redlich, proposer, intel, landis, rigorous, ugaritic,
# Nearest to to: hellas, darryl, princip, nationalities, forgetful, deviant, lake, probus,
# Nearest to other: dominican, morisco, hostels, muscled, domicile, heralding, officiel, monde,
# Nearest to was: vile, converted, vla, unlike, aelius, mendeleev, malign, nailed,
# Nearest to than: browning, suitable, commitments, rascal, badgers, suitor, dragster, ece,
# Nearest to consists: papeete, localization, ukrainians, coahuila, whdh, subdivision, speck, liberaci,
# Nearest to http: htm, edu, php, sockets, www, html, papa, catmull,
# Nearest to discovered: decoration, romania, ochino, electronegative, farid, orbit, encounter, evocation,
# Nearest to rise: orlogsflag, chechen, climatic, auguste, blok, lien, petrarca, cimbri,
# Nearest to hold: clogged, perceptions, inconceivable, serb, pressburger, hulbert, provincial, commission,
# Nearest to units: upwards, scorch, treize, amman, undefended, gluon, humps, segmenting,
# Nearest to universe: analytical, evelyn, tng, disputing, alterations, catalysis, plze, tenderness,
# Nearest to running: scouring, retort, sanjaks, gurps, rcmp, coventry, retaken, drastically,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1865 0.0288 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0845 0.0279 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0970 0.0278 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1322 0.0278 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0087 0.0339 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1073 0.0325 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1233 0.0279 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1000 0.0280 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1698 0.0075 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0753 0.0279 sec/batch
# Nearest to states: klm, prosperous, cabell, multiparty, baruch, campeador, angola, violated,
# Nearest to people: cjls, tangiers, takings, horde, finkelstein, from, shops, bolsheviks,
# Nearest to or: settings, hovd, basslines, assess, mascarenes, hrvatske, certify, wrexham,
# Nearest to and: cleverness, proposer, intel, redlich, luxemburg, ugaritic, predictably, rigorous,
# Nearest to to: hellas, darryl, forgetful, princip, lake, deviant, nationalities, carrying,
# Nearest to other: dominican, morisco, hostels, muscled, domicile, sufferers, heralding, buryat,
# Nearest to was: converted, unlike, vile, vla, nailed, malign, elsie, aelius,
# Nearest to than: browning, suitable, commitments, rascal, ece, dragster, badgers, exoplanets,
# Nearest to consists: papeete, localization, ukrainians, coahuila, whdh, subdivision, liberaci, speck,
# Nearest to http: htm, edu, www, php, sockets, html, geocities, papa,
# Nearest to discovered: decoration, romania, electronegative, ochino, farid, orbit, encounter, evocation,
# Nearest to rise: orlogsflag, chechen, climatic, auguste, petrarca, corona, blok, counteract,
# Nearest to hold: clogged, perceptions, inconceivable, provincial, serb, commission, pressburger, taft,
# Nearest to units: upwards, scorch, treize, gluon, humps, undefended, nanometres, segmenting,
# Nearest to universe: evelyn, analytical, tng, plze, catalysis, alterations, disputing, tenderness,
# Nearest to running: retort, gurps, scouring, sanjaks, rcmp, drastically, resets, retaken,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0540 0.0289 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0495 0.0279 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0458 0.0280 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0340 0.0278 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0715 0.0315 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0384 0.0342 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0937 0.0280 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0847 0.0280 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0864 0.0279 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0052 0.0320 sec/batch
# Nearest to states: prosperous, klm, multiparty, cabell, baruch, angola, campeador, canada,
# Nearest to people: cjls, takings, tangiers, horde, finkelstein, from, biya, shops,
# Nearest to or: settings, mascarenes, hovd, hrvatske, basslines, assess, wrexham, certify,
# Nearest to and: cleverness, proposer, ugaritic, intel, redlich, predictably, rigorous, luxemburg,
# Nearest to to: hellas, darryl, forgetful, lake, carrying, princip, nationalities, rammed,
# Nearest to other: dominican, morisco, hostels, muscled, sufferers, domicile, heralding, buryat,
# Nearest to was: converted, unlike, vla, nailed, vile, prevailed, malign, elsie,
# Nearest to than: browning, suitable, commitments, dragster, rascal, badgers, exoplanets, socialization,
# Nearest to consists: papeete, localization, ukrainians, coahuila, whdh, subdivision, liberaci, nominally,
# Nearest to http: htm, edu, php, www, html, geocities, sockets, papa,
# Nearest to discovered: decoration, electronegative, romania, ochino, farid, orbit, encounter, synthesized,
# Nearest to rise: orlogsflag, chechen, auguste, climatic, blok, petrarca, corona, cimbri,
# Nearest to hold: clogged, perceptions, provincial, pressburger, serb, inconceivable, commission, taft,
# Nearest to units: upwards, scorch, gluon, treize, humps, nanometres, undefended, amman,
# Nearest to universe: alterations, analytical, evelyn, disputing, tng, catalysis, plze, cosmological,
# Nearest to running: retort, gurps, sanjaks, rcmp, scouring, drastically, resets, retaken,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0430 0.0338 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0304 0.0280 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0200 0.0277 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0335 0.0279 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0515 0.0278 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0752 0.0279 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0437 0.0280 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1155 0.0277 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0452 0.0279 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0618 0.0278 sec/batch
# Nearest to states: prosperous, klm, cabell, baruch, multiparty, angola, campeador, law,
# Nearest to people: cjls, takings, tangiers, finkelstein, from, horde, namath, arjuna,
# Nearest to or: settings, hovd, hrvatske, assess, basslines, mascarenes, certify, wrexham,
# Nearest to and: cleverness, intel, proposer, rigorous, ugaritic, predictably, redlich, lactamase,
# Nearest to to: hellas, darryl, forgetful, nationalities, princip, lake, deviant, select,
# Nearest to other: dominican, morisco, hostels, muscled, domicile, heralding, sufferers, officiel,
# Nearest to was: converted, unlike, vile, vla, nailed, elsie, hippolyte, eprint,
# Nearest to than: suitable, browning, badgers, rascal, exoplanets, commitments, dragster, socialization,
# Nearest to consists: localization, papeete, coahuila, ukrainians, whdh, subdivision, nominally, ietf,
# Nearest to http: htm, edu, php, www, html, geocities, sockets, papa,
# Nearest to discovered: decoration, electronegative, romania, orbit, ochino, farid, encounter, iarc,
# Nearest to rise: chechen, orlogsflag, climatic, counteract, causing, auguste, blok, petrarca,
# Nearest to hold: clogged, perceptions, pressburger, provincial, inconceivable, serb, condemnations, connected,
# Nearest to units: upwards, scorch, gluon, nanometres, treize, humps, kilogram, telharmonium,
# Nearest to universe: alterations, analytical, catalysis, disputing, evelyn, tng, bang, cosmological,
# Nearest to running: retort, gurps, sanjaks, resets, rcmp, scouring, drastically, retaken,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0942 0.0289 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0715 0.0281 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0965 0.0280 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0371 0.0279 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0784 0.0279 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0401 0.0278 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0457 0.0280 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0355 0.0278 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0846 0.0281 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0627 0.0279 sec/batch
# Nearest to states: baruch, prosperous, cabell, klm, multiparty, campeador, geisel, angola,
# Nearest to people: cjls, tangiers, takings, horde, finkelstein, from, alaska, biya,
# Nearest to or: settings, hovd, hrvatske, mascarenes, assess, basslines, glissando, punctuation,
# Nearest to and: cleverness, proposer, intel, predictably, ugaritic, redlich, rigorous, luxemburg,
# Nearest to to: hellas, darryl, princip, nationalities, forgetful, lake, carrying, schiavo,
# Nearest to other: dominican, morisco, muscled, domicile, hostels, heralding, officiel, sufferers,
# Nearest to was: converted, vile, unlike, vla, nailed, aelius, eprint, elsie,
# Nearest to than: suitable, browning, exoplanets, rascal, commitments, badgers, dragster, ece,
# Nearest to consists: papeete, localization, coahuila, ukrainians, whdh, nominally, subdivision, ietf,
# Nearest to http: htm, edu, www, php, html, sockets, geocities, papa,
# Nearest to discovered: decoration, romania, electronegative, orbit, ochino, farid, encounter, hemorrhage,
# Nearest to rise: chechen, orlogsflag, petrarca, blok, auguste, counteract, climatic, marxist,
# Nearest to hold: clogged, serb, perceptions, provincial, inconceivable, condemnations, pressburger, connected,
# Nearest to units: upwards, scorch, gluon, nanometres, telharmonium, kilogram, amman, undefended,
# Nearest to universe: alterations, evelyn, catalysis, analytical, cosmological, bang, disputing, tng,
# Nearest to running: retort, gurps, sanjaks, resets, rcmp, drastically, scouring, retaken,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0427 0.0290 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0133 0.0281 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0306 0.0279 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0753 0.0281 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0729 0.0279 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1344 0.0279 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1323 0.0279 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0462 0.0278 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0312 0.0279 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0475 0.0278 sec/batch
# Nearest to states: klm, baruch, prosperous, multiparty, cabell, geisel, campeador, angola,
# Nearest to people: cjls, tangiers, takings, horde, finkelstein, alaska, biya, namath,
# Nearest to or: settings, hrvatske, hovd, mascarenes, punctuation, assess, basslines, glissando,
# Nearest to and: proposer, intel, predictably, cleverness, redlich, rigorous, joaqu, deutsches,
# Nearest to to: hellas, darryl, princip, nationalities, forgetful, carrying, deviant, schiavo,
# Nearest to other: dominican, morisco, hostels, domicile, muscled, officiel, heralding, sufferers,
# Nearest to was: converted, unlike, vile, vla, elsie, nailed, aelius, hippolyte,
# Nearest to than: suitable, browning, exoplanets, dragster, rascal, commitments, ece, badgers,
# Nearest to consists: papeete, localization, coahuila, ukrainians, whdh, subdivision, speck, rin,
# Nearest to http: htm, edu, www, php, geocities, html, sockets, eliade,
# Nearest to discovered: decoration, romania, ochino, electronegative, orbit, farid, encounter, evangelische,
# Nearest to rise: chechen, orlogsflag, climatic, blok, counteract, petrarca, causing, lukashenko,
# Nearest to hold: clogged, provincial, perceptions, serb, pressburger, condemnations, inconceivable, connected,
# Nearest to units: upwards, scorch, kilogram, gluon, telharmonium, nanometres, amman, undefended,
# Nearest to universe: alterations, evelyn, catalysis, tng, disputing, analytical, cosmological, bang,
# Nearest to running: retort, gurps, sanjaks, rcmp, resets, retaken, coventry, scouring,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9717 0.0288 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0236 0.0281 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0278 0.0278 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0498 0.0278 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0576 0.0278 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0277 0.0285 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9774 0.0280 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9479 0.0280 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9869 0.0278 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9602 0.0279 sec/batch
# Nearest to states: klm, prosperous, baruch, angola, cabell, multiparty, violated, law,
# Nearest to people: cjls, tangiers, takings, finkelstein, horde, alaska, arjuna, namath,
# Nearest to or: settings, hovd, hrvatske, assess, mascarenes, punctuation, basslines, glissando,
# Nearest to and: proposer, intel, cleverness, predictably, redlich, moclobemide, joaqu, covenant,
# Nearest to to: hellas, darryl, princip, nationalities, carrying, forgetful, schiavo, permissions,
# Nearest to other: dominican, morisco, hostels, domicile, muscled, sufferers, heralding, officiel,
# Nearest to was: converted, unlike, vla, nailed, vile, aelius, elsie, freebsd,
# Nearest to than: suitable, browning, exoplanets, dragster, equatoguinean, rascal, ece, commitments,
# Nearest to consists: papeete, localization, coahuila, ukrainians, whdh, subdivision, nominally, speck,
# Nearest to http: htm, edu, www, geocities, php, html, sockets, eliade,
# Nearest to discovered: decoration, electronegative, orbit, ochino, farid, romania, hemorrhage, encounter,
# Nearest to rise: chechen, orlogsflag, counteract, blok, climatic, petrarca, auguste, unconnected,
# Nearest to hold: clogged, provincial, perceptions, pressburger, condemnations, connected, serb, inconceivable,
# Nearest to units: upwards, kilogram, scorch, telharmonium, nanometres, gluon, undefended, amman,
# Nearest to universe: alterations, tng, disputing, evelyn, bang, tenderness, melton, plze,
# Nearest to running: retort, gurps, sanjaks, resets, rcmp, retaken, scouring, coventry,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9952 0.0289 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9458 0.0280 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0004 0.0278 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0137 0.0278 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0100 0.0279 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9931 0.0279 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8964 0.0279 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9780 0.0277 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9479 0.0278 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9868 0.0278 sec/batch
# Nearest to states: prosperous, klm, angola, baruch, law, canada, multiparty, cabell,
# Nearest to people: cjls, takings, tangiers, finkelstein, horde, arjuna, supportive, alaska,
# Nearest to or: settings, hrvatske, mascarenes, assess, hovd, basslines, punctuation, glissando,
# Nearest to and: proposer, predictably, intel, cleverness, covenant, moclobemide, lactamase, malignant,
# Nearest to to: hellas, darryl, nationalities, forgetful, princip, carrying, select, permissions,
# Nearest to other: dominican, morisco, muscled, hostels, domicile, sufferers, heralding, roam,
# Nearest to was: converted, unlike, nailed, vla, vile, certifying, aelius, elsie,
# Nearest to than: suitable, browning, exoplanets, equatoguinean, ece, dragster, rascal, kilometres,
# Nearest to consists: papeete, localization, coahuila, ukrainians, whdh, nominally, liberaci, subdivision,
# Nearest to http: htm, edu, www, geocities, html, php, sockets, eliade,
# Nearest to discovered: decoration, electronegative, orbit, ochino, romania, fossilized, farid, encounter,
# Nearest to rise: chechen, orlogsflag, blok, counteract, auguste, petrarca, climatic, ethnological,
# Nearest to hold: clogged, pressburger, provincial, perceptions, connected, serb, taft, hulbert,
# Nearest to units: upwards, kilogram, gluon, nanometres, telharmonium, scorch, mi, latino,
# Nearest to universe: alterations, bang, disputing, tng, catalysis, evelyn, melton, tenderness,
# Nearest to running: gurps, sanjaks, retort, resets, retaken, rcmp, runs, tackle,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0005 0.0288 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0033 0.0281 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0016 0.0278 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0139 0.0279 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0167 0.0279 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9734 0.0279 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9896 0.0292 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9864 0.0279 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9931 0.0279 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9981 0.0278 sec/batch
# Nearest to states: klm, prosperous, baruch, angola, exceptionally, multiparty, cabell, canada,
# Nearest to people: cjls, tangiers, takings, finkelstein, horde, alaska, encyclopedias, namath,
# Nearest to or: settings, mascarenes, assess, punctuation, basslines, hrvatske, glissando, hovd,
# Nearest to and: intel, predictably, proposer, joaqu, cleverness, rigorous, psychological, covenant,
# Nearest to to: hellas, darryl, nationalities, princip, select, schiavo, permissions, forgetful,
# Nearest to other: dominican, morisco, muscled, hostels, domicile, heralding, sufferers, officiel,
# Nearest to was: converted, unlike, nailed, elsie, vile, certifying, eprint, mendeleev,
# Nearest to than: browning, suitable, exoplanets, equatoguinean, ece, rascal, socialization, asian,
# Nearest to consists: papeete, localization, coahuila, whdh, ukrainians, nominally, rin, ietf,
# Nearest to http: htm, edu, www, html, geocities, php, sockets, eliade,
# Nearest to discovered: decoration, electronegative, orbit, ochino, fossilized, romania, farid, iarc,
# Nearest to rise: chechen, orlogsflag, counteract, blok, lukashenko, petrarca, marxist, auguste,
# Nearest to hold: clogged, provincial, pressburger, perceptions, connected, serb, taft, hulbert,
# Nearest to units: upwards, kilogram, telharmonium, nanometres, gluon, scorch, fluorescence, latino,
# Nearest to universe: bang, disputing, alterations, catalysis, tng, melton, cosmological, tenderness,
# Nearest to running: sanjaks, retort, gurps, resets, retaken, rcmp, tackle, coventry,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9878 0.0289 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9841 0.0281 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9863 0.0279 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0151 0.0279 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0184 0.0279 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9872 0.0278 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9868 0.0279 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9762 0.0279 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9815 0.0278 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0316 0.0280 sec/batch
# Nearest to states: klm, baruch, prosperous, angola, multiparty, law, exceptionally, mikael,
# Nearest to people: cjls, takings, tangiers, finkelstein, alaska, horde, sizeable, namath,
# Nearest to or: settings, assess, mascarenes, hovd, glissando, punctuation, hrvatske, basslines,
# Nearest to and: joaqu, predictably, intel, proposer, deutsches, moclobemide, psychological, luxemburg,
# Nearest to to: hellas, darryl, nationalities, princip, schiavo, carrying, forgetful, soros,
# Nearest to other: dominican, morisco, domicile, muscled, heralding, officiel, hostels, roam,
# Nearest to was: converted, unlike, vla, elsie, aelius, certifying, vile, nailed,
# ...
# Nearest to other: dominican, of, morisco, apart, andean, cites, roam, domicile,
# Nearest to was: unlike, converted, time, hippolyte, freebsd, elsie, lifeguard, kojiki,
# Nearest to than: more, equatoguinean, kilometres, asian, lifetime, inherited, undeserved, suitable,
# Nearest to consists: localization, papeete, coahuila, loaders, whdh, vas, weddings, kasay,
# Nearest to http: htm, www, edu, html, geocities, php, eliade, fanclub,
# Nearest to discovered: decoration, synthesized, ochino, farid, hemorrhage, hipparcos, iarc, traded,
# Nearest to rise: counteract, blok, chechen, judaea, lansbury, causing, petrarca, fortuitous,
# Nearest to hold: clogged, may, provincial, socialism, billie, taft, perceptions, pressburger,
# Nearest to units: kilogram, makeup, gram, si, latino, mi, gluon, telharmonium,
# Nearest to universe: bang, termini, melton, alterations, cosmological, catalysis, subsystems, disputing,
# Nearest to running: mountains, sanjaks, resets, lifeson, occupies, retort, runs, backs,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8486 0.0289 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8717 0.0278 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8890 0.0278 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8959 0.0280 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.9227 0.0277 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8870 0.0279 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8745 0.0281 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8469 0.0278 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8934 0.0277 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9097 0.0279 sec/batch
# Nearest to states: united, deus, law, vacated, subsystems, joiner, coincidentally, exceptionally,
# Nearest to people: cjls, takings, finkelstein, population, encyclopedias, tangiers, foreigners, meanings,
# Nearest to or: settings, use, adamic, unmarried, mix, ino, sep, plate,
# Nearest to and: is, are, one, many, more, deutsches, underpinnings, predictably,
# Nearest to to: hellas, also, carrying, without, nationalities, zairian, liquor, like,
# Nearest to other: dominican, apart, of, morisco, domicile, cites, perses, roam,
# Nearest to was: unlike, converted, time, kojiki, hippolyte, vile, quartet, elsie,
# Nearest to than: more, equatoguinean, kilometres, lifetime, suitable, brought, browning, undeserved,
# Nearest to consists: localization, papeete, coahuila, loaders, whdh, kasay, vas, ietf,
# Nearest to http: htm, www, edu, html, geocities, php, fanclub, sockets,
# Nearest to discovered: synthesized, decoration, ochino, farid, hipparcos, hemorrhage, discovery, dianetic,
# Nearest to rise: counteract, petrarca, blok, causing, chechen, judaea, fortuitous, lukashenko,
# Nearest to hold: clogged, may, billie, perceptions, provincial, socialism, taft, pressburger,
# Nearest to units: kilogram, si, mi, makeup, gram, latino, telharmonium, fayette,
# Nearest to universe: bang, termini, alterations, melton, catalysis, cosmological, subsystems, tycoon,
# Nearest to running: resets, mountains, sanjaks, retort, lifeson, shaken, occupies, runs,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8716 0.0291 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8762 0.0279 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8317 0.0280 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8545 0.0280 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9137 0.0281 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8478 0.0280 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9639 0.0279 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9246 0.0279 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9150 0.0280 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8380 0.0278 sec/batch
# Nearest to states: united, law, vacated, deus, mikael, coincidentally, joiner, wiggle,
# Nearest to people: cjls, takings, population, foreigners, finkelstein, namath, tangiers, meanings,
# Nearest to or: settings, use, jus, ino, adamic, mix, redneck, unmarried,
# Nearest to and: is, are, one, deutsches, more, most, underpinnings, many,
# Nearest to to: carrying, hellas, also, princip, nationalities, without, liquor, bianca,
# Nearest to other: of, dominican, apart, roam, six, domicile, perses, andean,
# Nearest to was: unlike, converted, successfully, kojiki, elsie, lifeguard, ce, time,
# Nearest to than: more, equatoguinean, lifetime, kilometres, suitable, brought, delgado, asian,
# Nearest to consists: localization, papeete, coahuila, loaders, whdh, weddings, vas, kasay,
# Nearest to http: htm, www, edu, html, geocities, fanclub, php, sockets,
# Nearest to discovered: synthesized, decoration, ochino, farid, hemorrhage, traded, hipparcos, iarc,
# Nearest to rise: counteract, judaea, blok, petrarca, causing, chechen, fortuitous, lukashenko,
# Nearest to hold: may, clogged, taft, provincial, billie, socialism, payout, hulbert,
# Nearest to units: kilogram, gram, mi, si, unit, makeup, latino, fayette,
# Nearest to universe: bang, termini, alterations, catalysis, cosmological, melton, tycoon, tng,
# Nearest to running: mountains, sanjaks, resets, lifeson, shaken, retort, occupies, summed,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8267 0.0287 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8659 0.0279 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8167 0.0279 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8897 0.0279 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8617 0.0281 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.9173 0.0278 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8741 0.0214 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8896 0.0278 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8249 0.0277 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8862 0.0285 sec/batch
# Nearest to states: united, vacated, law, deus, coincidentally, wiggle, subsystems, joiner,
# Nearest to people: cjls, takings, population, encyclopedias, finkelstein, foreigners, meanings, autodidacts,
# Nearest to or: settings, use, all, adamic, sep, depending, redneck, a,
# Nearest to and: is, are, one, many, from, more, most, with,
# Nearest to to: carrying, also, hellas, the, without, liquor, nationalities, and,
# Nearest to other: of, apart, dominican, domicile, cites, roam, perses, andean,
# Nearest to was: unlike, converted, kojiki, successfully, time, ce, son, rearguard,
# Nearest to than: more, lifetime, equatoguinean, brought, hypersonic, kilometres, paycheck, suitable,
# Nearest to consists: localization, papeete, coahuila, loaders, follows, whdh, vas, weddings,
# Nearest to http: htm, www, edu, html, geocities, fanclub, php, com,
# Nearest to discovered: synthesized, ochino, decoration, hemorrhage, farid, traded, hipparcos, came,
# Nearest to rise: counteract, blok, judaea, petrarca, causing, chechen, fortuitous, coexist,
# Nearest to hold: may, clogged, billie, socialism, provincial, taft, pressburger, perceptions,
# Nearest to units: kilogram, si, unit, gram, telharmonium, makeup, mi, talvela,
# Nearest to universe: bang, termini, alterations, tycoon, cosmological, zenith, xander, catalysis,
# Nearest to running: mountains, sanjaks, resets, backs, lifeson, tackle, retort, occupies,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8182 0.0293 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8282 0.0282 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7989 0.0279 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8807 0.0278 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8790 0.0282 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8793 0.0280 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8736 0.0278 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7459 0.0279 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8504 0.0278 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8181 0.0281 sec/batch
# Nearest to states: united, law, vacated, canada, prosperous, deus, subsystems, coincidentally,
# Nearest to people: cjls, takings, encyclopedias, population, meanings, finkelstein, roughly, foreigners,
# Nearest to or: settings, all, use, depending, mix, sep, a, hrvatske,
# Nearest to and: is, one, are, most, from, the, for, many,
# Nearest to to: also, carrying, the, hellas, without, nationalities, like, liquor,
# Nearest to other: of, apart, cites, the, andean, dominican, roam, six,
# Nearest to was: unlike, converted, son, lifeguard, ce, kojiki, successfully, rearguard,
# Nearest to than: more, lifetime, brought, equatoguinean, kilometres, hypersonic, ninety, paycheck,
# Nearest to consists: localization, papeete, follows, coahuila, loaders, whdh, vas, kasay,
# Nearest to http: htm, www, edu, html, geocities, php, fanclub, com,
# Nearest to discovered: synthesized, decoration, hemorrhage, ochino, farid, hipparcos, traded, ubangi,
# Nearest to rise: counteract, blok, causing, petrarca, judaea, chechen, fortuitous, justus,
# Nearest to hold: may, clogged, billie, payout, socialism, jack, provincial, taft,
# Nearest to units: kilogram, gram, unit, makeup, si, telharmonium, mi, latino,
# Nearest to universe: bang, termini, cosmological, alterations, cosmology, tycoon, subsystems, singularities,
# Nearest to running: mountains, sanjaks, resets, backs, retort, tackle, occupies, lifeson,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8071 0.0286 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8540 0.0278 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8605 0.0277 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8119 0.0278 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8497 0.0279 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9153 0.0280 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8353 0.0278 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8218 0.0278 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8734 0.0278 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8553 0.0280 sec/batch
# Nearest to states: united, vacated, law, deus, coincidentally, subsystems, canada, joiner,
# Nearest to people: cjls, takings, roughly, population, ohlin, foreigners, encyclopedias, recipients,
# Nearest to or: settings, use, depending, all, jus, traditional, mix, adamic,
# Nearest to and: is, are, one, from, most, underpinnings, more, many,
# Nearest to to: also, without, hellas, nationalities, the, carrying, liquor, inquart,
# Nearest to other: of, apart, dominican, six, andean, the, cites, roam,
# Nearest to was: unlike, converted, kojiki, ce, son, certifying, lifeguard, not,
# Nearest to than: more, brought, lifetime, equatoguinean, hypersonic, paycheck, delgado, kilometres,
# Nearest to consists: localization, loaders, follows, papeete, coahuila, whdh, weddings, dysfunction,
# Nearest to http: htm, www, html, edu, geocities, fanclub, php, eliade,
# Nearest to discovered: synthesized, decoration, hemorrhage, ochino, hipparcos, traded, farid, dianetic,
# Nearest to rise: counteract, causing, blok, fortuitous, lansbury, chechen, petrarca, wished,
# Nearest to hold: may, clogged, socialism, billie, payout, provincial, taft, lead,
# Nearest to units: kilogram, gram, si, unit, telharmonium, makeup, gluon, housing,
# Nearest to universe: bang, termini, cosmological, alterations, cosmology, subsystems, tycoon, catalysis,
# Nearest to running: mountains, resets, sanjaks, tackle, goes, backs, circumvented, retort,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8849 0.0288 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8873 0.0279 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8421 0.0280 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8395 0.0279 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8880 0.0279 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8565 0.0278 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8644 0.0278 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8523 0.0279 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8245 0.0279 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8331 0.0279 sec/batch
# Nearest to states: united, coincidentally, vacated, law, deus, subsystems, superior, episcopalians,
# Nearest to people: cjls, takings, population, roughly, foreigners, philosophers, americans, incheon,
# Nearest to or: settings, use, depending, jus, all, a, traditional, hrvatske,
# Nearest to and: is, are, one, from, more, the, most, many,
# Nearest to to: also, the, carrying, without, of, nationalities, hellas, inherit,
# Nearest to other: of, apart, six, the, roam, domicile, dominican, andean,
# Nearest to was: unlike, converted, kojiki, ce, time, certifying, it, mistranslation,
# Nearest to than: more, lifetime, brought, paycheck, equatoguinean, hypersonic, delgado, eq,
# Nearest to consists: localization, coahuila, papeete, follows, loaders, whdh, dysfunction, weddings,
# Nearest to http: htm, www, edu, html, geocities, fanclub, php, eliade,
# Nearest to discovered: synthesized, decoration, hemorrhage, ochino, hipparcos, traded, came, dianetic,
# Nearest to rise: counteract, causing, blok, chechen, petrarca, judaea, lukashenko, fortuitous,
# Nearest to hold: may, clogged, socialism, billie, payout, perceptions, provincial, lead,
# Nearest to units: kilogram, gram, unit, si, telharmonium, makeup, clk, talvela,
# Nearest to universe: bang, termini, cosmological, alterations, tycoon, cosmology, plze, subsystems,
# Nearest to running: mountains, resets, sanjaks, goes, retort, circumvented, tackle, backs,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8940 0.0289 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8658 0.0278 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9588 0.0278 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9204 0.0280 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9165 0.0278 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7991 0.0279 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7802 0.0276 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8782 0.0278 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7871 0.0278 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8718 0.0281 sec/batch
# Nearest to states: united, coincidentally, superior, vacated, episcopalians, prosperous, law, subsystems,
# Nearest to people: cjls, population, takings, philosophers, foreigners, roughly, bw, living,
# Nearest to or: settings, jus, use, all, depending, ino, timetables, a,
# Nearest to and: is, are, from, most, more, underpinnings, s, one,
# Nearest to to: also, hellas, nationalities, carrying, the, inherit, without, former,
# Nearest to other: apart, of, domicile, roam, andean, dominican, perses, the,
# Nearest to was: unlike, converted, time, not, certifying, but, were, ce,
# Nearest to than: more, lifetime, equatoguinean, kilometres, brought, paycheck, hypersonic, suitable,
# Nearest to consists: localization, papeete, follows, coahuila, loaders, whdh, of, hooft,
# Nearest to http: www, htm, edu, html, geocities, php, fanclub, eliade,
# Nearest to discovered: synthesized, decoration, ochino, came, hemorrhage, lizzy, traded, farid,
# Nearest to rise: counteract, causing, petrarca, blok, chechen, judaea, fortuitous, lukashenko,
# Nearest to hold: may, clogged, billie, payout, socialism, perceptions, provincial, taft,
# Nearest to units: kilogram, si, unit, gram, cgs, telharmonium, clk, makeup,
# Nearest to universe: bang, termini, cosmological, alterations, plze, tycoon, cosmology, subsystems,
# Nearest to running: mountains, sanjaks, resets, goes, circumvented, backs, lifeson, archenemy,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8381 0.0289 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8613 0.0277 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# ## ...Need optimization of hyperparameters
